# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 6))
#mpl.rc('image', cmap='gray')
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims
import trackpy as tp
import cv2
from pims import Frame
from scipy.misc import imsave

# %%
v = pims.TiffStack('/Users/pinghanchu/Documents/Git/Data/Shot119_Cam_18333.tif')
u = pims.TiffStack('/Users/pinghanchu/Documents/Git/Data/Shot119_Cam_18158.tif')
v0 = tp.bandpass(v[0],1, 300)
u0 = tp.bandpass(u[0],1, 300)
imsave("v0.png",v0)
imsave("u0.png",u0)
plt.imshow(u0)
# Out:
# /Users/pinghanchu/anaconda/lib/python2.7/site-packages/tifffile/tifffile.py:2126: UserWarning: invalid page offset > file size
#   warnings.warn("invalid page offset > file size")

# %%
plt.imshow(v0)

# %%
from PIL import Image
img = Image.open("u0.png")
img2 = img.rotate(5)
img2
# Out:
# <PIL.Image.Image image mode=L size=384x384 at 0x1192AA910>

# %%
import cv2
import numpy as np

img = cv2.imread('u0.png',0)
#cv2.imshow(img)
rows,cols = img.shape
print(rows,cols)

#M = np.float32([[1,0,100],[0,1,50]])
#dst = cv2.warpAffine(img,M,(cols,rows))

#cv2.imshow('img',dst)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
