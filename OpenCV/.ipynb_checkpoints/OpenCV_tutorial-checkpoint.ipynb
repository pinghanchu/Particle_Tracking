# %%
##Load an image
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('messi.jpg',1)

# %%
##Write an image
#cv2.imwrite('messigray.png',img)

# %%
##Show an image
#cv2.imshow('image',img)#
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
#import numpy as np
#import cv2

#img = cv2.imread('messi.jpg',0)
#cv2.imshow('image',img)
#k = cv2.waitKey(0)
#if k == 27:         # wait for ESC key to exit
#    cv2.destroyAllWindows()
#elif k == ord('s'): # wait for 's' key to save and exit
#    cv2.imwrite('messigray.png',img)
#    cv2.destroyAllWindows()

# %%
#import numpy as np
#import cv2
#from matplotlib import pyplot as plt

#img = cv2.imread('messi.jpg',0)
#plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
#plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
#plt.show()

# %%
#The image is a big matrix
#Each pixel is an array if three color (blue, green, red)
px = img[100,100]
print(px)
print(type(px))
# Out:
# [36 66 91]
# <type 'numpy.ndarray'>

# %%
#Red color
img.item(1,1,2)
# Out:
# 38

# %%
#Reset pixel value
img.itemset((10,10,2),100)
img.item(10,10,2)
# Out:
# 100

# %%
#Print image size
print(img.size)
#Print image type
print(img.dtype)
#Print image shape
print(img.shape)
# Out:
# 766800
# uint8
# (600, 426, 3)

# %%
#Copy and Paster
#test = img[0:10, 0:10]
#img[100:110, 100:110] = test

# %%
#flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
#print flags

# %%
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
#cv2.imshow('image',img)
#cv2.imshow('image2',img2)
#cv2.imshow('image1',img1)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in xrange(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
img = cv2.imread('/Users/pinghanchu/Documents/Git/Data/Clean_Data_Shot119_Cam_18158/frame_1001.png',0)
img = cv2.medianBlur(img,1)

ret,th1 = cv2.threshold(img,10,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,3,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,3,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in xrange(4):
    #plt.subplot(2,2,i+1),
    plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
plt.imsave("test.png",th3)

# %%
img = cv2.imread('/Users/pinghanchu/Documents/Git/Data/Clean_Data_Shot119_Cam_18158/frame_1001.png',0)
blur = cv2.GaussianBlur(img,(5,5),0)

# find normalized_histogram, and its cumulative distribution function
hist = cv2.calcHist([blur],[0],None,[256],[0,256])
hist_norm = hist.ravel()/hist.max()
Q = hist_norm.cumsum()

bins = np.arange(256)

fn_min = np.inf
thresh = -1

for i in xrange(1,256):
    p1,p2 = np.hsplit(hist_norm,[i]) # probabilities
    q1,q2 = Q[i],Q[255]-Q[i] # cum sum of classes
    b1,b2 = np.hsplit(bins,[i]) # weights

    # finding means and variances
    m1,m2 = np.sum(p1*b1)/q1, np.sum(p2*b2)/q2
    v1,v2 = np.sum(((b1-m1)**2)*p1)/q1,np.sum(((b2-m2)**2)*p2)/q2

    # calculates the minimization function
    fn = v1*q1 + v2*q2
    if fn < fn_min:
        fn_min = fn
        thresh = i

# find otsu's threshold value with OpenCV function
ret, otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
print(thresh,ret)
plt.imshow(otsu,'gray')
plt.show()
plt.imsave("test2.png",otsu)
# Out:
# (75, 74.0)
# /Users/pinghanchu/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in double_scalars
# /Users/pinghanchu/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/pinghanchu/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in multiply

# %%
import cv2
import numpy as np

img = cv2.imread('messi.jpg',0)

plt.imshow(img)
plt.show()
res = cv2.resize(img,None,fx=2, fy=2)
plt.imshow(res)
plt.show()
plt.imsave("messi2.png",img)

# %%
img = plt.imread('messi.jpg')
plt.imshow(img)
plt.show()
res = cv2.resize(img,None,fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
plt.imshow(res)
plt.show()
plt.imsave("messi2.png",img)
img.shape
#res.shape
# Out:
# (600, 426, 3)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img1 = plt.imread('messi.jpg')
img2 = cv2.imread('messi.jpg',0)
plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()
print(img1.shape)
row,col,color = img1.shape
rows,cols = img2.shape
print(row,col)
M = np.float32([[1,0,100],[0,1,50]])
dst = cv2.warpAffine(img1,M,(cols,rows))
#print(dst)
plt.figure()
plt.imshow(dst)
plt.show()
#plt.imsave("messi3.png",dst)
#dst.shape
#cv2.imshow('img',dst)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# (600, 426, 3)
# (600, 426)

# %%
img = plt.imread('messi.jpg',0)
rows,cols,co = img.shape

M = cv2.getRotationMatrix2D((cols/3,rows/3),45,1)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.figure()
plt.imshow(dst)
plt.show()

# %%
img = plt.imread('messi.jpg',0)
rows,cols,ch = img.shape
cv2.rectangle(rec,rows*2, cols*2)
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])

M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
